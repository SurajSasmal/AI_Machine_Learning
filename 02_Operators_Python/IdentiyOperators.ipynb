# %%
a = 10
b = 20 

print(a is b)
print(a is not b)
print(id(a))
print(id(b))
# Out:
# False
# True
# 140722238776728
# 140722238777048

# %%
a = 20
b = 20

print(a is b)
print(id(a))
print(id(b))
# Out:
# True
# 140722238777048
# 140722238777048

# %%
a = 20
b = a

print(a is b)
# Out:
# True

# %%
a = [10,20,30,40,50]
b = [30,40]

print(b is a)
print(b is not a)
# Out:
# False
# True

# %%
a = [10,20,30,40,50]
b = [10,20,30,40,50]


print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2599449729600
# 2599449891136
