# %%
# Addition
a = 10 
b = 5 
print(a + b)
# Out:
# 15

# %%
# Subtraction 
a = 121
b = 65

print(a - b)
# Out:
# 56

# %%
# Multiplication
a = 34
b = 12
print(a * b)
# Out:
# 408

# %%
# Divison 
a = 345
b = 23
print(a / b)
# Out:
# 15.0

# %%
# Floor Divison 
a = 456
b = 25
print(a // b)
# Out:
# 18

# %%
# Modolus 
a = 345
b = 24
print(a % b)
# Out:
# 9

# %%
# Expontention 
a = 4
b = 4

print(a ** b)
# Out:
# 256

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))

print("Addition :",num1 + num2)
print("Subtraction :",num1 - num2)
print("Multiplication :",num1 * num2)
print("Division :",num1 / num2)
print("Floor Division :",num1 // num2)
print("Modulus :",num1 % num2)
print("Exponentation :",num1 ** num2)
# Out:
# Addition : 79
# Subtraction : 55
# Multiplication : 804
# Division : 5.583333333333333
# Floor Division : 5
# Modulus : 7
# Exponentation : 8182718904632857144561
